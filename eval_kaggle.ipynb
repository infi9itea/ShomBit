# %%
# !git clone https://github.com/infi9itea/ragbot.git
# %cd ragbot
# !pip install -q -r requirements.txt

import os

os.environ["HF_TOKEN"]     = "your_hf_token_here"
os.environ["GROQ_API_KEY"] = "your_groq_key_here"

os.environ["DATA_DIR"] = "/kaggle/input/datasets/mrnotalent/ewu-data/data-1"

# !python eval_all.py
