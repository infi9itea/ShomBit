# %%
# !git clone https://github.com/infi9itea/ragbot.git
# %cd ragbot
# !pip install -q -r requirements.txt

import os

os.environ["HF_TOKEN"] = "your_hf_token_here"
os.environ["NGROK_TOKEN"] = "your_ngrok_token_here"

os.environ["DATA_DIR"] = "/kaggle/input/datasets/mrnotalent/ewu-data/new_rag"

# !python app.py
